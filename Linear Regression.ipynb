# %%
# https://github.com/codebasics/py/blob/master/ML/13_kmeans/Exercise/13_kmeans_exercise.ipynb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("/Users/hirdeshpal/Downloads/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df['area'],df['price'],color = 'blue')
plt.title("Plot price per Square fit")
plt.plot(df['area'],reg.predict(df[['area']]),color = 'red')

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict(np.array([[3300]]))  #Reshape the scalar value 3300 into a 2D array using numpy or a nested list.
# Out:
# /Users/hirdeshpal/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
#### linear eq^n:     y=mx+c
#### for above eq^n:  price = m * area + c
#### m(slope or coef_) = 135.78767123
#### c(intercept)     = 180616.43835616432

# %%
## or
price = 135.78767123*3300 + 180616.43835616432
price
# Out:
# 628715.7534151643

# %%
p = pd.read_csv("/Users/hirdeshpal/Downloads/areas.csv")
p
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
prices = reg.predict(p)
prices
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
p['prices'] = prices

# %%
p
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
p.to_csv('solution')

# %% [markdown]
# ### Excercise

# %%
df1 = pd.read_csv("/Users/hirdeshpal/Downloads/canada_per_capita_income.csv")
df1.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.scatter(df1['year'],df1['per capita income (US$)'])
plt.title('Canda per year income')
plt.xlabel('Prices')
plt.ylabel('Year')
plt.show()

# %%
reg1 = LinearRegression()
reg1.fit(df1[['year']],df1['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
p1 = reg1.predict(np.array([[2023]]))
# Out:
# /Users/hirdeshpal/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(f"the price will be: {p1} $$")
# Out:
# the price will be: [43774.08932009] $$

# %% [markdown]
# ## Linear Regression Multiple Variables

# %%
df2 = pd.read_csv("/Users/hirdeshpal/Downloads/homeprices-2.csv")
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df2.bedrooms.median()
# Out:
# 4.0

# %%
df2['bedrooms'].fillna(3.5, inplace  = True)

# %%
reg3 = linear_model.LinearRegression()

# %%
df2.columns
# Out:
# Index(['area', 'bedrooms', 'age', 'price'], dtype='object')

# %%
reg3.fit(df2[['area', 'bedrooms', 'age']],
         df2['price'])
# Out:
# LinearRegression()

# %%
reg3.coef_
# Out:
# array([  110.76035614, 23256.46711536, -3238.45104247])

# %%
reg3.intercept_
# Out:
# 228372.65131819982

# %%
reg3.predict([[3000,4,15]])
# Out:
# /Users/hirdeshpal/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([605102.82257708])

# %%
from sklearn.model_selection import train_test_split

# %%
X,y = df2[['area', 'bedrooms', 'age']].values,df2['price'].values
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=0)
reg3 =

# %%
y
# Out:
# array([550000, 565000, 610000, 595000, 760000, 810000])

# %%
reg3 =linear_model.LinearRegression()

# %%
reg3.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred  = reg3.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pred  = reg3.predict(X_test)
#
# NameError: name 'reg3' is not defined
