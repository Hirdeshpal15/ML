# %% [markdown]
# ![Screenshot 2025-02-06 at 6.27.18 PM.png](attachment:b650b6df-8c2b-43f7-8a20-8e3579d5281a.png)

# %% [markdown]
# ![Screenshot 2025-02-06 at 6.58.13 PM.png](attachment:b5d40d55-d37d-46a4-9163-8be70d867a2d.png)

# %% [markdown]
# ![Screenshot 2025-02-06 at 6.58.29 PM.png](attachment:001565d2-0f4d-4bc7-a3e3-01e85839992b.png)
